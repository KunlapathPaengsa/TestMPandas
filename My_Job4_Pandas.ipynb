# %% [markdown]
# <a href="https://colab.research.google.com/github/KunlapathPaengsa/TestMyPandas/blob/main/My_Job4_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
APP_PATH = "/content/drive/My Drive/Pandas.Kunlapath/17k-apple-app-store-strategy-games.zip"

# %%
APP_PATH
# Out:
# '/content/drive/My Drive/Pandas.Kunlapath/17k-apple-app-store-strategy-games.zip'

# %%
df_apps = pd.read_csv(APP_PATH)

# %%
df_apps.shape
# Out:
# (17007, 18)

# %%
df_apps.columns
# Out:
# Index([u'URL', u'ID', u'Name', u'Subtitle', u'Icon URL',
#        u'Average User Rating', u'User Rating Count', u'Price',
#        u'In-app Purchases', u'Description', u'Developer', u'Age Rating',
#        u'Languages', u'Size', u'Primary Genre', u'Genres',
#        u'Original Release Date', u'Current Version Release Date'],
#       dtype='object')

# %%
df_apps.head()
# Out:
#                                                  URL  ...  Current Version Release Date
# 0   https://apps.apple.com/us/app/sudoku/id284921427  ...                    30/05/2017
# 1  https://apps.apple.com/us/app/reversi/id284926400  ...                    17/05/2018
# 2  https://apps.apple.com/us/app/morocco/id284946595  ...                     5/09/2017
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  ...                    30/05/2017
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  ...                    22/07/2018
#
# [5 rows x 18 columns]

# %%
df_apps.head(3)
# Out:
#                                                  URL  ...  Current Version Release Date
# 0   https://apps.apple.com/us/app/sudoku/id284921427  ...                    30/05/2017
# 1  https://apps.apple.com/us/app/reversi/id284926400  ...                    17/05/2018
# 2  https://apps.apple.com/us/app/morocco/id284946595  ...                     5/09/2017
#
# [3 rows x 18 columns]

# %%
df_apps.tail(3)
# Out:
#                                                      URL  ...  Current Version Release Date
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                     3/08/2019
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  ...                     1/08/2019
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  ...                     2/08/2019
#
# [3 rows x 18 columns]

# %%
df_apps.sample()
# Out:
#                                                     URL  ...  Current Version Release Date
# 4663  https://apps.apple.com/us/app/3d-jungle-monkey...  ...                     5/10/2014
#
# [1 rows x 18 columns]

# %%
df_apps.sample(3)
# Out:
#                                                     URL  ...  Current Version Release Date
# 5752  https://apps.apple.com/us/app/whodunnit-murder...  ...                    28/10/2017
# 2530  https://apps.apple.com/us/app/age-of-warriors-...  ...                    19/12/2018
# 2254  https://apps.apple.com/us/app/d-d-lords-of-wat...  ...                    21/09/2017
#
# [3 rows x 18 columns]

# %%
df_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
# URL                             17007 non-null object
# ID                              17007 non-null int64
# Name                            17007 non-null object
# Subtitle                        5261 non-null object
# Icon URL                        17007 non-null object
# Average User Rating             7561 non-null float64
# User Rating Count               7561 non-null float64
# Price                           16983 non-null float64
# In-app Purchases                7683 non-null object
# Description                     17007 non-null object
# Developer                       17007 non-null object
# Age Rating                      17007 non-null object
# Languages                       16947 non-null object
# Size                            17006 non-null float64
# Primary Genre                   17007 non-null object
# ...

# %%
df_apps.describe()
# Out:
#                  ID  Average User Rating  ...         Price          Size
# count  1.700700e+04          7561.000000  ...  16983.000000  1.700600e+04
# mean   1.059614e+09             4.060905  ...      0.813419  1.157064e+08
# std    2.999676e+08             0.751428  ...      7.835732  2.036477e+08
# min    2.849214e+08             1.000000  ...      0.000000  5.132800e+04
# 25%    8.996543e+08             3.500000  ...      0.000000  2.295014e+07
# 50%    1.112286e+09             4.500000  ...      0.000000  5.676895e+07
# 75%    1.286983e+09             4.500000  ...      0.000000  1.330271e+08
# max    1.475077e+09             5.000000  ...    179.990000  4.005591e+09
#
# [8 rows x 5 columns]

# %%
df_apps.describe(include="all")
# Out:
#                                                       URL  ...  Current Version Release Date
# count                                               17007  ...                         17007
# unique                                              16847  ...                          2512
# top     https://apps.apple.com/us/app/air-troops-littl...  ...                     1/08/2019
# freq                                                    2  ...                           118
# mean                                                  NaN  ...                           NaN
# std                                                   NaN  ...                           NaN
# min                                                   NaN  ...                           NaN
# 25%                                                   NaN  ...                           NaN
# 50%                                                   NaN  ...                           NaN
# ...

# %%
df_apps[5:10+1]
# Out:
#                                                   URL  ...  Current Version Release Date
# 5   https://apps.apple.com/us/app/sudoku-classic-n...  ...                    29/04/2019
# 6   https://apps.apple.com/us/app/gravitation/id28...  ...                    14/11/2013
# 7    https://apps.apple.com/us/app/colony/id286363959  ...                     3/10/2018
# 8     https://apps.apple.com/us/app/carte/id286566987  ...                    23/11/2017
# 9   https://apps.apple.com/us/app/barrels-o-fun/id...  ...                     1/08/2008
# 10  https://apps.apple.com/us/app/quaddraxx/id2875...  ...                    30/09/2008
#
# [6 rows x 18 columns]

# %%
df_apps[["Name","Subtitle"]][5:11]
# Out:
#                               Name                 Subtitle
# 5   Sudoku - Classic number puzzle  Original brain training
# 6                      Gravitation                      NaN
# 7                           Colony                      NaN
# 8                            Carte                      NaN
# 9                 "Barrels O' Fun"                      NaN
# 10                       Quaddraxx                      NaN

# %% [markdown]
# ค้นหาแอปที่เรตติ้งมากกว่า4.5 จำนวนมากกว่าหมื่นคน

# %%
df_apps.columns
# Out:
# Index([u'URL', u'ID', u'Name', u'Subtitle', u'Icon URL',
#        u'Average User Rating', u'User Rating Count', u'Price',
#        u'In-app Purchases', u'Description', u'Developer', u'Age Rating',
#        u'Languages', u'Size', u'Primary Genre', u'Genres',
#        u'Original Release Date', u'Current Version Release Date'],
#       dtype='object')

# %%
df_apps[(df_apps["Average User Rating"] > 4.5) & (df_apps["User Rating Count"] > 10000)]
# Out:
#                                                      URL  ...  Current Version Release Date
# 564    https://apps.apple.com/us/app/anthill/id414658364  ...                     3/09/2017
# 617    https://apps.apple.com/us/app/chess-tiger-pro/...  ...                    26/06/2019
# 805    https://apps.apple.com/us/app/tiny-defense/id4...  ...                    16/12/2017
# 872    https://apps.apple.com/us/app/naval-warfare/id...  ...                     2/06/2016
# 1039   https://apps.apple.com/us/app/kingdom-rush-hd/...  ...                    19/07/2019
# 1050   https://apps.apple.com/us/app/zombie-tower-sho...  ...                    17/10/2017
# 1260   https://apps.apple.com/us/app/kingdom-rush/id5...  ...                    16/07/2019
# 1356   https://apps.apple.com/us/app/fieldrunners-2/i...  ...                    11/04/2018
# 1597   https://apps.apple.com/us/app/naval-warfare-mu...  ...                     6/06/2016
# ...

# %%
df_apps[(df_apps["Average User Rating"] > 4.5) & (df_apps["User Rating Count"] > 10000)].shape
# Out:
# (67, 18)

# %%
pd.Series.to_frame(df_apps["Genres"].value_counts())
# Out:
#                                                     Genres
# Games, Strategy, Puzzle                                778
# Games, Puzzle, Strategy                                694
# Games, Strategy                                        588
# Games, Strategy, Action                                483
# Games, Simulation, Strategy                            465
# Games, Strategy, Simulation                            462
# Games, Action, Strategy                                421
# Games, Strategy, Puzzle, Entertainment                 357
# Games, Puzzle, Strategy, Entertainment                 342
# Games, Strategy, Casual                                339
# Games, Strategy, Entertainment, Puzzle                 336
# Games, Entertainment, Puzzle, Strategy                 316
# Games, Casual, Strategy                                309
# Games, Board, Strategy                                 304
# Games, Strategy, Board                                 295
# ...

# %%
df_cnt_genres[:11].plot(kind="bar")

# %%
 df_apps["Price Per User"]= df_apps["Price"]/df_apps["User Rating Count"]

# %%
 df_apps[["Price Per User","Price","User Rating Count"]][:3]
# Out:
#    Price Per User  Price  User Rating Count
# 0        0.000842   2.99             3553.0
# 1        0.007007   1.99              284.0
# 2        0.000000   0.00             8376.0

# %%
 df_apps[["Name","Price","Average User Rating","User Rating Count"]].sort_values(by="Price", ascending=False)[:5]
# Out:
#                                                    Name  ...  User Rating Count
# 8807  Cat Simulator: Cute Pet 3D Full - Be a kitten,...  ...                NaN
# 8600             Wild Falcon Survival Simulator 3D Full  ...                NaN
# 9219           Lion Simulator: Wild African Animal Full  ...                NaN
# 8281     Sea Turtle Simulator 3D Full - Ocean Adventure  ...                NaN
# 8177                       Wild Horse 3D Simulator Full  ...                NaN
#
# [5 rows x 4 columns]

# %%
  df_apps[["Average User Rating","User Rating Count"]] \
  = df_apps[["Average User Rating","User Rating Count"]].fillna(0)

# %% [markdown]
# อิมพิวเทชั่นด้วยฟังก์ชัน .fillna() ให้ค่า NaN เป็น 0

# %%
 df_apps[["Name","Price","Average User Rating","User Rating Count"]].sort_values \
 (by=["Price","Average User Rating","User Rating Count"], ascending=False)[:5]
# Out:
#                                                Name  ...  User Rating Count
# 8177                   Wild Horse 3D Simulator Full  ...                0.0
# 8196                Pony Survival Simulator 3D Full  ...                0.0
# 8198  T-rex Simulator 3D Full - Survival adventures  ...                0.0
# 8200             Unicorn Survival Simulator 3D Full  ...                0.0
# 8273                  Sea Dolphin Simulator 3D Full  ...                0.0
#
# [5 rows x 4 columns]

# %%
 df_apps[["Average User Rating","User Rating Count"]].describe()
# Out:
#        Average User Rating  User Rating Count
# count         17007.000000       1.700700e+04
# mean              1.805404       1.470023e+03
# std               2.079264       2.826616e+04
# min               0.000000       0.000000e+00
# 25%               0.000000       0.000000e+00
# 50%               0.000000       0.000000e+00
# 75%               4.000000       3.100000e+01
# max               5.000000       3.032734e+06

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_obj = MinMaxScaler((0,10))

# %%
df_apps[["Price","Average User Rating","User Rating Count"]] \
= min_max_obj.fit_transform(df_apps[["Price","Average User Rating","User Rating Count"]])

# %% [markdown]
# ทำ ฟีเจอร์สเกลลิ่ง เพื่อนอมอลไลเซชั่น (เปลี่ยนพิสัย)ไม่เหมือน สแตนดาร์ดไลเซชั่นที่เป็าเก๊าส์เซียน(ระฆังคว่ำ)

# %%
df_apps[["Price","Average User Rating","User Rating Count"]][:5]
# Out:
#       Price  Average User Rating  User Rating Count
# 0  0.166120                  8.0           0.011716
# 1  0.110562                  7.0           0.000936
# 2  0.000000                  6.0           0.027619
# 3  0.000000                  7.0           0.627797
# 4  0.166120                  7.0           0.000092

# %%
df_apps[["Price","Average User Rating","User Rating Count"]].describe()
# Out:
#               Price  Average User Rating  User Rating Count
# count  16983.000000         17007.000000       17007.000000
# mean       0.045192             3.610807           0.004847
# std        0.435343             4.158529           0.093204
# min        0.000000             0.000000           0.000000
# 25%        0.000000             0.000000           0.000000
# 50%        0.000000             0.000000           0.000000
# 75%        0.000000             8.000000           0.000102
# max       10.000000            10.000000          10.000000

# %% [markdown]
# หาคาเฉลี่ยของทั้งสามคอลัมน์ ราคา เรตติ้ง จำนวนรีวิว

# %%
df_apps[["Price","Average User Rating","User Rating Count"]].mean()
# Out:
# Price                  0.045192
# Average User Rating    3.610807
# User Rating Count      0.004847
# dtype: float64

# %%
df_apps[["Price","Average User Rating","User Rating Count"]].mean(axis=1)
# Out:
# 0        2.725945
# 1        2.370499
# 2        2.009206
# 3        2.542599
# 4        2.388738
# 5        2.000052
# 6        1.666705
# 7        1.685138
# 8        1.666715
# 9        1.666869
# 10       0.000000
# 11       2.338908
# 12       2.000578
# 13       2.352755
# 14       1.669258
# 15       2.000123
# 16       2.000123
# 17       2.000554
# 18       2.438817
# 19       2.333726
# 20       2.018342
# 21       1.351701
# 22       0.000000
# 23       0.018334
# 24       2.685701
# 25       2.335051
# 26       2.768059
# 27       2.412940
# 28       1.685210
# 29       1.722116
#            ...
# 16977    0.000000
# 16978    0.000000
# 16979    0.000000
# 16980    0.000000
# 16981    0.000000
# 16982    0.000000
# 16983    0.000000
# 16984    0.000000
# 16985    0.000000
# 16986    0.000000
# 16987    0.018334
# 16988    0.000000
# 16989    0.000000
# 16990    0.000000
# 16991    0.000000
# 16992    0.000000
# 16993    3.333370
# 16994    0.018334
# 16995    0.036854
# ...

# %% [markdown]
# เฉลี่ยที่ละคน

# %%
df_apps["avg_lux"] =\
df_apps[["Price","Average User Rating","User Rating Count"]].mean(axis=1)

# %%
df_luxe_apps =\
df_apps[["Name","avg_lux"]].sort_values(by=["avg_lux"], ascending=False)

# %%
df_luxe_apps[:5]
# Out:
#                             Name   avg_lux
# 1378              Clash of Clans  6.333333
# 2634   Finabase: realtime stocks  5.593759
# 7187                Clash Royale  4.403678
# 13414                PUBG MOBILE  3.781923
# 15031             GOTO Bridge 19  3.777709

# %%
"/content/drive/My Drive/Pandas.Kunlapath/luxe_apps.xlsx"
# Out:
# '/content/drive/My Drive/Pandas.Kunlapath/luxe_apps.xlsx'

# %%
df_luxe_apps.to_excel('/content/drive/My Drive/Pandas.Kunlapath/luxe_apps.xlsx')

# %%
df_luxe_apps[:10].plot(kind="hist")
